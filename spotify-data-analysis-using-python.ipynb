# %% [markdown]
# ![spotify1.png](attachment:924d31d1-a70c-404a-acd0-c07aa49edf91.png) ![py100.png](attachment:623804d3-3457-4311-a322-f94af67b2ca5.png)
#
# # Spotify Data Analysis using Python
# **I'm sharing an Exploratory Data Analysis (EDA) and Data Visualization of the data from Spotify using Python - A Data Analysis Project performed in Kaggle Notebook.**

# %% [markdown]
# ## About the project ##
#
# Spotify is the world’s most popular audio streaming subscription service with more than 500 million users, including 205 million subscribers in more than 180 markets.
#
# * In this project, l have explored and quantified data about music and drawn valuable insights.
#
# * Conducted data cleaning to perform exploratory data analysis (EDA) and data visualization of the Spotify dataset using Python (Pandas, NumPy, Matplotlib and Seaborn).
#
# * Data analysis - Exploring the relationship between the audio features of a song and how positive or negative its lyrics are, involving sentiment analysis and much more.
#
# * Spotify Data Analysis makes use of secondary data from Spotify. Use data to identify patterns and relationships between different characteristics. The activity will support in developing ability to review and interpret a dataset.

# %% [markdown]
# ## Technologies used ##
#
# * Python
#
# * statistics
#
# ### Python Libraries ###
#
# * Pandas | Numpy | Matplotlib | Seaborn

# %% [markdown]
# ## Project - Spotify Data Analysis using Python ##
#
# #### Objective ####
#
# **1. Top 10 most popular songs.**
#
# **2. Top 10 least popular songs.**
#
# **3. Top 20 songs with popularity more than 90%**
#
# **4. Correlation Heatmap between Variable**
#
# **5. Regression plot - Correlation between Loudness and Energy**
#
# **6. Regression plot - Correlation between Popularity and Acousticness**
#
# **7. Bar plot - Duration of the songs in different genres**
#
# **8. Bar plot - Top 10  Popular Genres**

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading Datasets and First 10 rows
df_track = pd.read_csv('/kaggle/input/spotifydatabase/SpotifyDB.csv')
df_track.head(10)
# Out:
#    genre          artist_name  \
# 0  Movie       Henri Salvador
# 1  Movie    Martin & les fées
# 2  Movie      Joseph Williams
# 3  Movie       Henri Salvador
# 4  Movie         Fabien Nataf
# 5  Movie       Henri Salvador
# 6  Movie    Martin & les fées
# 7  Movie          Laura Mayne
# 8  Movie               Chorus
# 9  Movie  Le Club des Juniors
#
#                                           track_name                track_id  \
# 0                        C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                   Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2                     Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3                     Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                          Ouverture  0IuslXpMROHdEPvSl1fTQK
# 5                     Le petit souper aux chandelles  0Mf1jKa8eNAf1a4PwTbizj
# 6  Premières recherches (par Paul Ventimila, Lori...  0NUiKYRd6jt1LKMYGkUdnZ
# ...

# %%
#Checking the description of the data using describe() function present in pandas
df_track.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %%
#Checking Datatypes of the dataset
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
#Checking null values in dataset
df_track.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %% [markdown]
# As you can see there is no null values in our dataset, so we can move forward and do another analysis.

# %% [markdown]
# #### Now, to get a list of least popular songs, we’ll sort the column popularity in ascending order using the SQL function called **sort_values().** ####

# %%
#Checking Top 10 most popular songs.
df_popular_songs = df_track.sort_values('popularity', ascending= False).head(10)
df_popular_songs
# Out:
#             genre    artist_name                                track_name  \
# 9027        Dance  Ariana Grande                                   7 rings
# 107804        Pop  Ariana Grande                                   7 rings
# 86951         Rap    Post Malone                                      Wow.
# 107803        Pop    Post Malone                                      Wow.
# 107802        Pop  Ariana Grande  break up with your girlfriend, i'm bored
# 9026        Dance  Ariana Grande  break up with your girlfriend, i'm bored
# 66643     Hip-Hop   Daddy Yankee                                 Con Calma
# 107909        Pop   Daddy Yankee                                 Con Calma
# 138918  Reggaeton   Daddy Yankee                                 Con Calma
# 107829        Pop        Ava Max                          Sweet but Psycho
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
#Checking Top 10 least popular songs.
df_least_popular_songs = df_track.sort_values('popularity', ascending= True).head(10)
df_least_popular_songs
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# ...

# %% [markdown]
# #### Top 20 songs with popularity more than 90% ####

# %%
df_most_popular_songs = df_track.query('popularity > 90',inplace = False).sort_values('popularity', ascending = False)
df_most_popular_songs[:20]
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
# 92824       Indie         Halsey
# 9037        Dance        Ava Max
# 9028        Dance         Halsey
# 107875        Pop     Pedro Capó
# 107806        Pop    Post Malone
# 107808        Pop         Halsey
# 107810        Pop      Sam Smith
# 107812        Pop     Marshmello
# 107829        Pop        Ava Max
# 66607     Hip-Hop        J. Cole
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# ...

# %% [markdown]
# #### Correlation Map ####
#
# Now, we will create our first visualization. To do so, we need to drop three columns that aren’t needed for this type of visualization: mode and key, as well as the pearson correlation method. We will set the figure size for the correlation map to (14,6). Here is a color map reference. You can google sns cmap and choose any color from the documentation, if you wish.

# %%
corr_df = df_track.drop(['key','mode'], axis = 1).corr(method = 'pearson')
plt.figure(figsize = [14,6])
heatmap = sns.heatmap(corr_df, annot = True, fmt = '.1g', vmin = -1, vmax = 1, center = 0, cmap = 'inferno', linecolor = 'Black')
heatmap.set_title('Correlation HeatMap Between Variable')
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation = 90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'acousticness'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'duration_ms'),
#  Text(4.5, 0, 'energy'),
#  Text(5.5, 0, 'instrumentalness'),
#  Text(6.5, 0, 'liveness'),
#  Text(7.5, 0, 'loudness'),
#  Text(8.5, 0, 'speechiness'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'valence')]

# %% [markdown]
# #### Let’s Move Forward and Sample Only 4% Percent of the Whole Dataset.

# %%
sample_df = df_track.sample(int(0.004 * len(df_track)))
sample_df
# Out:
#                    genre         artist_name               track_name  \
# 154844              Rock    A Perfect Circle    By And Down The River
# 13515        Alternative       Bishop Briggs                  Hold On
# 97910   Children’s Music               Dawes       When My Time Comes
# 148481              Jazz         Jaimee Paul   Days Of Wine And Roses
# 11923        Alternative        Chris Tomlin  God's Great Dance Floor
# ...                  ...                 ...                      ...
# 16193              Dance   Flight Facilities                Crave You
# 223335              Rock              The xx                   Angels
# 194381             Movie        Randy Newman                A New Day
# 65760               Folk           Bob Seger          The Fire Inside
# 184287             Movie  Richard M. Sherman        Panic At The Bank
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %% [markdown]
# #### Let’s create a regression plot that shows the relationship between loudness and energy.
#
# We will use a function regplot() present in the seaborn library that allows us to draw regression plots easily.

# %%
plt.figure(figsize = [10, 6])
sns.regplot(data = sample_df, y = 'loudness', x = 'energy', color = 'c')
# Out:
# <AxesSubplot:xlabel='energy', ylabel='loudness'>

# %% [markdown]
# The result is plotted. As the volume gets louder, the energy values go up. The data points provided are all in one direction, which means that as the volume goes up, so does the energy level. The volume of the song increases in correlation with the pitch, so that if a song is louder, it simultaneously sounds fast. Similarly, if a song’s pitch is higher, its volume also increases correspondingly; if the pitch decreases and gets lower-pitched, then its volume also lowers to match this.
# Similarly, we can also plot another regression plot between popularity and acousticness.

# %% [markdown]
# #### This chart will show the strong correlation between popularity and acousticness of songs.

# %%
plt.figure(figsize = [10, 6])
sns.regplot(data = sample_df, y = 'popularity', x = 'acousticness', color = 'g')
# Out:
# <AxesSubplot:xlabel='acousticness', ylabel='popularity'>

# %% [markdown]
# When we look at the green line in this graph, it is downwards, which signifies that if the acousticness of the song increases, the popularity decreases. Correspondingly, if the popularity increases or even stays stable, the acousticness decreases.

# %% [markdown]
# #### The duration of songs varies quite a lot by the genre.
#
# We will use a function called barplot that is present in the seaborn library.

# %%
plt.figure(figsize = [15, 6])
plt.title('Duration of the songs in different genres')
sns.color_palette('rocket', as_cmap = True)
sns.barplot(y = 'genre', x = 'duration_ms', data = df_track)
# Out:
# <AxesSubplot:title={'center':'Duration of the songs in different genres'}, xlabel='duration_ms', ylabel='genre'>

# %% [markdown]
# Here, we got the genres on the Y-axis and duration in milliseconds on the X-axis. The data tells us that classical and world genres have a longer duration of songs than music categorized as being for children.

# %% [markdown]
# #### Find Top 10 genres by Popularity and plot a barplot for the same.

# %%
sns.set_style(style = 'darkgrid')
plt.figure(figsize = [10,6])
most_popular_genres = df_track.sort_values('popularity', ascending = False).head(10)
sns.barplot(y = 'genre', x = 'popularity', data = most_popular_genres).set(title = "Top 10  Popular Genres")
# Out:
# [Text(0.5, 1.0, 'Top 10  Popular Genres')]

# %% [markdown]
# **If you want a different color pallettes then you can find it on seaborn.pydata.org**

# %% [markdown]
# #### We can do more analysis based search and plot a chart accordingly.
